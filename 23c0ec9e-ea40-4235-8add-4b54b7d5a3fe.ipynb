# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# Здравствуй. Теперь мои комментарии будут отмечены так
#
# <h2> Комментарий ревьюера_V3 <a class="tocSkip"> </h2>
#
# Спасибо за доработку. Проект принят. Желаю удачи в дальнейшем обучении.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# Привет еще раз. Я буду также выделять свои комментарии цветом, но сейчас они будут отмечены так
#
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Илья, привет!👋</b>
#
# Меня зовут Горбунова Анастасия, и я буду давать обратную связь по твоему проекту. Предлагаю общаться на "ты", но если это  неудобно, обязательно скажи об этом, и мы перейдем на "вы"! Моя основная задача - поделиться своим опытом и помочь тебе пройти путь до аналитика данных.
#
# Чтобы тебе проще было ориентироваться, мои комментарии будут отмечены <font color='green'>👍 зеленым</font>, <font color='Orange'>💡 желтым</font> и <font color='red'>❌ красным</font> цветами:
#
#
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично! 👍:</b>
#
# Таким цветом отмечены правильные и удачные решения, на которые можно опираться в будущих проектах.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые рекомендации 💡:</b>
#
# Так отмечены комментарии-рекомендации на будущее или небольшие коррективы. Ты можешь учесть эти комментарии при выполнении следующих проектов.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Красным цветом отмечены комментарии, которые требуют твоего внимания. Решение на этом этапе требует переработки или внесения правок. После доработки проект будет принят.
# </div>
#
#
# В случае доработки проекта оставь все предыдущие комментарии без изменения. Пожалуйста, не удаляй, не перемещай и не изменяй мои комментарии. Это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
# Также прошу реагировать на мои комментарии своими: если ты что-то меняешь в проекте по моим рекомендациям - пиши об этом в ячейке Markdown. Выдели свои комментарии каким-либо другим заметным цветом, явно  отличающимся от цвета моих комментариев. Это нужно, чтобы не создавалась путаница и было проще отследить изменения.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <b>Комментарий студента</b>
#
# Это шаблон для тебя, можешь воспользоваться им, или сделать по своему усмотрению. Так я смогу быстро найти твои комментарии.
# </div>

# %% [markdown]
# ***Сборный проект №1
#
# Описание проекта
# В этом проекте мы будем работать с открытыми данными о продажах игр для интернет-магазина «Стримчик» который продаёт по всему миру компьютерные игры. Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламную компанию на 2017 год.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
#
#
# <font color='red'><b>На доработку ❌:</b>  </font>
#
# Проект стоит начинать с заголовка. А также добавить введение: краткое описание проекта, цель проекта, описание данных, план работы. Тогда получатель отчета сможет быстрей его понять.
#
# Чего точно в твоем проекте не хватает и отчего он однозначно бы выиграл - это наличие некоей структуры. Названия разделов, подразделов.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍

# %% [markdown]
# ***Случайно удалил твой комментарий (жёлтый)(
#
# ***Часть 1.
#
# Загружаем файл с данными и изучаем общую информацию.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Если нужно вернуть удаленную ячейку, можно в панели меню нажать Edit --> Undo delete cells

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/datasets/games.csv')
data.columns = map(str.lower, data.columns)
data['year_of_release'] = pd.to_datetime(data['year_of_release'], format= '%Y') # Меняем на дату
data['year_public'] = data['year_of_release'].dt.year

data['user_score'] = data['user_score'].replace('tbd', np.NaN)
#print(data['user_score'].unique()) # 'tbd' - заменим на NaN
data['user_score'] = data['user_score'].astype(float) # Меняем обьект на число. чтобы можно было работать с цифрами

data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1) # считаем общую сумму

display(data.head(5))
data.info()
display(data.isna().sum())  # Смотрим пропуски
# Out:
#                        name platform year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii      2006-01-01        Sports     41.36
# 1         Super Mario Bros.      NES      1985-01-01      Platform     29.08
# 2            Mario Kart Wii      Wii      2008-01-01        Racing     15.68
# 3         Wii Sports Resort      Wii      2009-01-01        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    year_public  total_sales
# 0       2006.0        82.54
# 1       1985.0        40.24
# ...

# %%
duplicat = data[data.duplicated ()]
print(duplicat) # Дубликатов строк не найдено
dupl = data.duplicated(['name']).sum() # найденны дубликаты названий игр
print(dupl)
data_dup = data.pivot_table(index='name', values='platform', aggfunc = sum) # Некрасивое решение, но тут мы видим что игры дублируются по платформам (что логично)
display(data_dup.head(20))
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, year_public, total_sales]
# Index: []
# 5155
#                                                       platform
# name
#  Beyblade Burst                                            3DS
#  Fire Emblem Fates                                         3DS
#  Frozen: Olaf's Quest                                    3DSDS
#  Haikyu!! Cross Team Match!                                3DS
#  Tales of Xillia 2                                         PS3
# '98 Koshien                                                 PS
# .hack//G.U. Vol.1//Rebirth                                 PS2
# .hack//G.U. Vol.2//Reminisce                               PS2
# .hack//G.U. Vol.2//Reminisce (jp sales)                    PS2
# .hack//G.U. Vol.3//Redemption                              PS2
# .hack//Infection Part 1                                    PS2
# ...

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h3> Комментарий ревьюера <a class="tocSkip"> </h3>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Стоит большие блоки кода разбивать логически: загрузка библиотек, загрузка данных, обзор данных, подсчет пропусков, приведение формата данных, расчет суммарных продаж и т.д. Такой код и читать легче и отлаживать.
#
# Попробуй вывести табличные данные через display, а не print, и ты увидишь, насколько удобнее станет восприниматься информация.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Ты делаешь абсолютно правильно, что сначала заменяешь значения tbd на NaN в колонке user_score, т.к. метод astype не сработает при наличии в колонке нечисловых символов или неоднородных значений (в нашем случае - tbd), потому что не сможет преобразовать текст в тип float.
#
# Можно воспользоваться функцией to_numeric, которая позволит обойти значения tbd и автоматически заменит это недопустимое значение на значение NaN с помощью передачи аргумента errors=coerce. В таком случае не понадобится выполнять дополнительные преобразования, чтобы изменение типа работало правильно.
#
# Вот здесь можно почитать более подробно про  вспомогательные функции pandas: https://dfedorov.spb.ru/pandas/%D0%9E%D0%B1%D0%B7%D0%BE%D1%80%20%D1%82%D0%B8%D0%BF%D0%BE%D0%B2%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85%20pandas.html
#
# </div>

# %% [markdown]
# ***Часть 1. Подготовка данных
#
# TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований. (поэтому предлагаю заполнить пропуски неопределённым)
#
# critic_score       8578
# user_score         9125
# rating             6766
# Надо придумать как обработать эти пропуски! Заменить их средним медианой может есть какой иной хитрый способ.
#
#
# ***Не все пропуски обработаны или прокомментированы. Остались пропуски в названии игры, жанре, года выпуска, рейтинга.
#
# В нашем конкретном случае я пропустил работу над этими пропусками потомучто в последствии при работе с данными с 2010 (а в последствии 2014) года они ушли.
#
# **дубликаты строк не выявлены, но выявленны в названиях игр это обусловленно выходом игр на рвзных платформах!

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Оставить пропуски в данных critic_score и user_score - верное решение. Так ты исключаешь вероятность включить в анализ нереальные данные. Главное не забывать их исключать на стадии проверки гипотез.
#
# </div>

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Как ты думаешь, что будет, если попробовать заменить пропуски в столбце rating на значение Unknown?
#
# </div>

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Не все пропуски обработаны или прокомментированы. Остались пропуски в названии игры, жанре, года выпуска, рейтинга.
#
# В данном разделе у тебя не описаны причины, которые могли привести к пропускам. Измени, пожалуйста, вывод.
#
# Стоит добавлять в работу проверку данных на дубликаты. В некоторых исследованиях дубликаты могут серьезно исказить результаты и привести к ошибочным выводам.
#
# </div>

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Не забывай выделять новые этапы анализа разделами и заголовками.

# %% [markdown]
# ***Часть 2. Подготовка данных

# %%
data.hist('year_public', bins = 36) # Изменил кол-во корзин на 36
data_top = data.pivot_table(index='year_public', columns = 'platform', values='total_sales', aggfunc = sum) 
# Собираем промежуточные данные 
print('Медианное значение жизни игровой платформы:', data_top.count().sort_values(ascending=False).median())
display(data_top.head(5))
# Out:
# Медианное значение жизни игровой платформы: 7.0
# platform      2600  3DO  3DS  DC  DS  GB  GBA  GC  GEN  GG  ...  SAT  SCD  \
# year_public                                                 ...
# 1980.0       11.38  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN
# 1981.0       35.68  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN
# 1982.0       28.88  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN
# 1983.0        5.84  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN
# 1984.0        0.27  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  ...  NaN  NaN
#
# platform     SNES  TG16  WS  Wii  WiiU  X360  XB  XOne
# year_public
# 1980.0        NaN   NaN NaN  NaN   NaN   NaN NaN   NaN
# 1981.0        NaN   NaN NaN  NaN   NaN   NaN NaN   NaN
# 1982.0        NaN   NaN NaN  NaN   NaN   NaN NaN   NaN
# 1983.0        NaN   NaN NaN  NaN   NaN   NaN NaN   NaN
# 1984.0        NaN   NaN NaN  NaN   NaN   NaN NaN   NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
#
#
# В наших данных - 37 лет.

# %%
platform_sales = data.pivot_table(index='platform', values='total_sales', aggfunc = sum)
platform_sales.columns = ['all_ad']
platform_sales = platform_sales.sort_values('all_ad', ascending=False) # находи топ 10
display('Топ-10 продаваймых платформ', platform_sales.head(10))
# Out:
# 'Топ-10 продаваймых платформ'
#            all_ad
# platform
# PS2       1255.77
# X360       971.42
# PS3        939.65
# Wii        907.51
# DS         806.12
# PS         730.86
# GBA        317.85
# PS4        314.14
# PSP        294.05
# PC         259.52

# %%
platforms_name = data['platform'].unique()

import matplotlib.pyplot as plt

for platform in platforms_name:
    subset = data[data['platform'] == platform].pivot_table(index='year_public', values='total_sales', aggfunc = sum).plot(
        kind='bar', figsize=(13,6))
    plt.title(platform)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
#
# <font color='red'><b>На доработку ❌:</b>  </font>
#
# 1. Твой код сейчас разбит на огромные блоки, при этом вывод промежуточных результатов удален или порядок вывода результатов на экран нарушен. Пожалуйста, разбей код на небольшие блоки, добавь вывод промежуточных результатов.
#
# 2. Чтобы гистограмма отразилась корректно, количество bins нужно задать равным количеству лет в данных. Какой период совсем не значим для анализа, когда было критически мало выпуска игр?
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Если ты используешь визуализацию в проекте, стоит уделять больше времени ее оформлению: ко всем графикам в проекте важно добавлять общий заголовок, подписи к осям, убрать технические строчки . Это помогает сразу считать информацию. Пожалуйста, скорректируй графики во всем проекте:)
#
# Ниже добавляю ссылки по оформления графиков в библиотеках seaborn и matplotlib:
#
# https://pyprog.pro/mpl/mpl_title.html
#
# https://pyprog.pro/mpl/mpl_axis_signatures.html
#
# https://pythobyte.com/matplotlib-bar-80584/
#
# https://devpractice.ru/matplotlib-lesson-3-3-text-elements/
#
# https://pythobyte.com/matplotlib-bar-80584/
#
# https://www.dataforeverybody.com/change-seaborn-title-chart-axes-font/
#
# https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size-in-matplotlib
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://www.python-graph-gallery.com/4-add-title-and-axis-label
#
# </div>

# %% [markdown]
# ***Часть 2. Общий вывод
#
# Исходя из то что мы планируем кампанию на 2017-й. Я бы не использовал данные после 2010 года. Раз в 5 лет у нас есть пики покупок!
# И к сожалению мы этот пик уже прошли тоесть расчитывать в общем на сверх прибыли в 2017г не стоит, к тому же наложилось смена покалений консолей (7 лет)!  Сами графики платформ показывают в общем и целом нормальное распределение!
# Платформы с максимальными продажами, уже давно вышли в тираж!
# PS2       1255.77
# X360       971.42
# PS3        939.65
# Wii        907.51
# DS         806.12
#
#
# ***когда было критически мало выпуска игр?
#
# В периоде с 1980 по 1995 года игр выходило крайне мало.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Оставив 2011 год обязательно захватишь уже отжившие тренды, т.к. в 2011г. есть еще старые пиковые данные для "мертвых" платформ, а это "шум", дающий искажение. Я бы сказала, что максимально допустимый период - 5 лет. Но и слишком короткий период тоже брать не стоит.
#
# </div>

# %% [markdown]
# ***Часть 3  Проводим исследовательский анализ данных

# %%
data_11 = data.query('year_public > 2013') # Формирем таблиу с данными от 2014 г
data_11
display(data_11.isna().sum()) # Пропало часть пропусков 
data_11['platform'].unique()
# Out:
# name                 0
# platform             0
# year_of_release      0
# genre                0
# na_sales             0
# eu_sales             0
# jp_sales             0
# other_sales          0
# critic_score       971
# user_score         801
# rating             749
# year_public          0
# total_sales          0
# dtype: int64
# array(['PS4', '3DS', 'XOne', 'WiiU', 'PS3', 'X360', 'PC', 'Wii', 'PSV',
#        'PSP'], dtype=object)

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.

# %%
platforms_name = data_11['platform'].unique() # смотрим какими платформами мы вообще будем работать!

import matplotlib.pyplot as plt

for platform in platforms_name:
    subset = data_11[data_11['platform'] == platform].pivot_table(index='year_public', values='total_sales', aggfunc = sum).plot(
        kind='bar', figsize=(13,6))
    plt.title(platform)
# Строим такиеже графики как и в прошлой секции и изучаем полученные данные!

# %%
top_platform = data_11[data_11['platform'].isin(['PS4', '3DS', 'XOne', 'WiiU', 'PC'])].reset_index() 
print(top_platform['platform'].unique())
print(top_platform)
# Out:
# ['PS4' '3DS' 'XOne' 'WiiU' 'PC']
#       index                                               name platform  \
# 0        31                          Call of Duty: Black Ops 3      PS4
# 1        42                                 Grand Theft Auto V      PS4
# 2        47          Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 3        77                                            FIFA 16      PS4
# 4        87                       Star Wars Battlefront (2015)      PS4
# ...     ...                                                ...      ...
# 1035  16660                                   Prison Architect     XOne
# 1036  16668  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 1037  16672      Metal Gear Solid V: The Definitive Experience     XOne
# 1038  16677                   Aikatsu Stars! My Special Appeal      3DS
# 1039  16692                  Metal Gear Solid V: Ground Zeroes       PC
#
# ...

# %% [markdown]
# ***Часть 3. Проводим исследовательский анализ данных
#
# Исходя из построенных нами графиков мы можем отобрать наиболее перспективные платформы, но рынок падает (тут мы попали видимо в смену поколений консолей, следующий пик будет через 5 лет)!
# PS4, 3DS, **XOne**, Wii, PC далее будем работать с этими платформами. но к сожалению и доходы по этим платформам тоже снижаются!
#
# ***можно ли и дальше утверждать, что все продажи по всем платформам снижаются?
#
# Да изходя из построенных нами гистограмм видно что в целом после пика в 2015 году продажи в 2016 году снизились, и общий тренд в целом это снижение продаж из-за смены поколений консолей.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# 👍

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# В целом логика анализа в твоем решении верная. Согласна с выводами по лидерам. В условиях задачи была информация, что данные продаж за 2016 год могут быть неполными. Принимая во внимание это условие, можно ли и дальше утверждать, что все продажи по всем платформам снижаются?
#
# В top_platform ты отбираешь XOne, а в выводе пишешь XBOX. Это разные платформы.
#
# </div>

# %%
import seaborn as sns
plt.figure(figsize=(16,36))
sns.boxplot(data=top_platform, x='platform', y='total_sales') # Строим ящик с усами по выбранным платформам
# Out:
# <AxesSubplot:xlabel='platform', ylabel='total_sales'>

# %% [markdown]
# ***Часть 3.1 Проводим исследовательский анализ данных
#
# Исходя из данных видим что больше всех продаж у PS4 и Xone, далее идет WiiU, ф РС и 3ДС замыкают рейтинги продаж!
#
# ***Не могу разобраться как пользоватся  ylim(((

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# `sns.boxplot(data=top_platform, x='platform', y='total_sales').set(ylim=(0,2))`

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Можно приблизить нижнюю часть боксплотов с помощью параметра ylim.

# %% [markdown]
# Часть 3.2 Проводим исследовательский анализ данных

# %%
ps4 = top_platform[top_platform['platform'].isin(['PS4'])].reset_index() 
print('Кореляция продаж и оценки критиков для ps4:', ps4['critic_score'].corr(ps4['total_sales']))
print('Кореляция продаж и оценки пользователей для ps4:', ps4['user_score'].corr(ps4['total_sales']))

ps4.plot(x='critic_score', y='user_score', style='o', alpha=0.4, kind='scatter', grid=True) # 
plt.title('Гистограммы для PS4')
ps4.plot(x='critic_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
ps4.plot(x='user_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
# Out:
# Кореляция продаж и оценки критиков для ps4: 0.40266141068104083
# Кореляция продаж и оценки пользователей для ps4: -0.040131589472697356

# %%
ds3 = top_platform[top_platform['platform'].isin(['3DS'])].reset_index() 
print('Кореляция продаж и оценки критиков для ds3:', ds3['critic_score'].corr(ds3['total_sales']))
print('Кореляция продаж и оценки пользователей для ds3:', ds3['user_score'].corr(ds3['total_sales']))
ds3.plot(x='critic_score', y='user_score', style='o', alpha=0.4, kind='scatter', grid=True) # 
plt.title('Гистограммы для 3DS')
ds3.plot(x='critic_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
ds3.plot(x='user_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
# Out:
# Кореляция продаж и оценки критиков для ds3: 0.314117492869051
# Кореляция продаж и оценки пользователей для ds3: 0.2151932718527028

# %%
XOne = top_platform[top_platform['platform'].isin(['XOne'])].reset_index() 
print('Кореляция продаж и оценки критиков для XOne:', XOne['critic_score'].corr(XOne['total_sales']))
print('Кореляция продаж и оценки пользователей для XOne:', XOne['user_score'].corr(XOne['total_sales']))
XOne.plot(x='critic_score', y='user_score', style='o', alpha=0.4, kind='scatter', grid=True) # 
plt.title('Гистограммы для XOne')
XOne.plot(x='critic_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
XOne.plot(x='user_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
# Out:
# Кореляция продаж и оценки критиков для XOne: 0.42867694370333226
# Кореляция продаж и оценки пользователей для XOne: -0.0703839280647581

# %%
WiiU = top_platform[top_platform['platform'].isin(['WiiU'])].reset_index() 
print('Кореляция продаж и оценки критиков для WiiU:', WiiU['critic_score'].corr(WiiU['total_sales']))
print('Кореляция продаж и оценки пользователей для WiiU:', WiiU['user_score'].corr(WiiU['total_sales']))
WiiU.plot(x='critic_score', y='user_score', style='o', alpha=0.4, kind='scatter', grid=True) # 
plt.title('Гистограммы для WiiU')
WiiU.plot(x='critic_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
WiiU.plot(x='user_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
# Out:
# Кореляция продаж и оценки критиков для WiiU: 0.370201412480884
# Кореляция продаж и оценки пользователей для WiiU: 0.40792645792170773

# %%
PC = top_platform[top_platform['platform'].isin(['PC'])].reset_index() 
print('Кореляция продаж и оценки критиков для PC:', PC['critic_score'].corr(PC['total_sales']))
print('Кореляция продаж и оценки пользователей для PC:', PC['user_score'].corr(PC['total_sales']))
PC.plot(x='critic_score', y='user_score', style='o', alpha=0.4, kind='scatter', grid=True) # 
plt.title('Гистограммы для PC')
PC.plot(x='critic_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
PC.plot(x='user_score', y='total_sales', style='o', alpha=0.4, kind='scatter', grid=True);
# Out:
# Кореляция продаж и оценки критиков для PC: 0.17463413769350036
# Кореляция продаж и оценки пользователей для PC: -0.07159665703472451

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
#
# Техническую строку `<AxesSubplot:...>` можно убрать с помощью метода plt.show() или добавления в конце кода `;`
#
#
# </div>

# %% [markdown]
# ***Часть 3.2 Проводим исследовательский анализ данных
#
# Кореляция продаж и оценки критиков для ps4: 0.40656790206178095
# Кореляция продаж и оценки критиков для ds3: 0.3487397305984834
# Кореляция продаж и оценки критиков для XOne: 0.4169983280084017
# Кореляция продаж и оценки критиков для WiiU: 0.34837976012017485
# Кореляция продаж и оценки критиков для PC: 0.3141847396903631
#
# Кореляция продаж и оценки пользователей для ps4: -0.040131589472697356
# Кореляция продаж и оценки пользователей для ds3: 0.2151932718527028
# Кореляция продаж и оценки пользователей для XOne: -0.0703839280647581
# Кореляция продаж и оценки пользователей для WiiU: 0.40792645792170773
# Кореляция продаж и оценки пользователей для PC: -0.07159665703472451
#
# Мы получили довольно умеренную кореляцию уровня продаж и оценки критиков для XOne и ps4 она выше!
# Из Графиков мы видим что что продажи в большей степени зависят от оценки пользователей В особенности для XOne.(старый вывод)
#
# ***Как ты определил, что для платформы XOne зависимость от оценок пользователей выше без расчетов коэффициентов. Скорректируй выводы после исправлений.
#
# Посчитал кореляцию продаж и оценки пользователей, еще раз убедились что японский рынок особенный. Есть зависимость только для WiiU и ds3.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Хорошо.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# По заданию необходимо посчитать коэффициент корреляции между отзывами пользователей и продажами.
#
# Как ты определил, что для платформы XOne зависимость от оценок пользователей выше без расчетов коэффициентов. Скорректируй выводы после исправлений.
#
# </div>

# %% [markdown]
# ***Часть 4. Составляем портрет пользователя каждого региона

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Портрет пользователей регионов будет дальше, сейчас анализ жанров.

# %%
genre_name = top_platform['genre'].unique() # Смотрим уникальные жанры.
#genre_top = top_platform.pivot_table(index = 'genre', values='total_sales', aggfunc = sum)
genre_top = top_platform.groupby('genre').agg({'total_sales':['count','median','mean', 'sum']}).reset_index() 
# Посмотрим на количество игр, медианные и средние значения.
print(genre_top)
data_11.plot(x='total_sales', y='genre', style='o', alpha=0.2, kind='scatter', grid=True)
# Out:
#            genre total_sales
#                        count median      mean     sum
# 0         Action         384  0.110  0.416849  160.07
# 1      Adventure          74  0.060  0.150676   11.15
# 2       Fighting          31  0.160  0.773548   23.98
# 3           Misc          72  0.105  0.319444   23.00
# 4       Platform          29  0.190  0.584483   16.95
# 5         Puzzle          11  0.060  0.191818    2.11
# 6         Racing          50  0.100  0.495600   24.78
# 7   Role-Playing         128  0.200  0.671484   85.95
# 8        Shooter          98  0.540  1.474184  144.47
# 9     Simulation          37  0.110  0.331892   12.28
# 10        Sports          94  0.240  0.816596   76.76
# 11      Strategy          32  0.060  0.116250    3.72
# <AxesSubplot:xlabel='total_sales', ylabel='genre'>

# %%
data_11.boxplot(column='total_sales', by='genre', figsize=(20,10))

plt.show()

# %% [markdown]
# ***Часть 4. Составляем портрет пользователя каждого региона
#
# Самые продаваемые жанры это Action 229.86, Shooter 179.04, Role-Playing 149.31, Sports 97.27!
# Puzzle 7.45, Strategy 13.51, Adventure 15.80 тут сымые низкие продажи (старкрафт окончательно вышел из моды).
#
# ***Построили ящик с усами в разбивке по жанрам у нас есть выбросы Shooter, Action и Role-Playing
#
# Дополнитеьно можем сделать вывод что жанры Shooter и  Sports емеют самые высокие показатели среднего и медианного значения продаж!

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Верно.

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи. Их поможет оценить график "ящик с усами" в разбивке по жанрам. Обязательно прокомментируй разницу после построения "ящика с усами".
#
#
# </div>

# %% [markdown]
# ***Шаг 4.1 Составляем портрет пользователя каждого региона

# %%
data_11
#data_11['platform'].unique()
reg_top = data_11.pivot_table(index = 'platform', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc = sum).reset_index()
display(reg_top) # Смотрим в общем как дела)

reg_top.sort_values('eu_sales', ascending=False).head(5).plot(x='eu_sales', y='platform', kind='scatter',  grid=True)
plt.title('Популярные платформы в Европе')
reg_top.sort_values('na_sales', ascending=False).head(5).plot(x='na_sales', y='platform', kind='scatter',  grid=True)
plt.title('Популярные платформы в Северной Америке')
reg_top.sort_values('jp_sales', ascending=False).head(5).plot(x='jp_sales', y='platform', kind='scatter',  grid=True)
plt.title('Популярные платформы в Японии')
reg_top.sort_values('other_sales', ascending=False).head(5).plot(x='other_sales', y='platform', kind='scatter',  grid=True)
plt.title('Популярные платформы в остальном мире')
# Out:
#   platform  eu_sales  jp_sales  na_sales  other_sales
# 0      3DS     16.12     44.24     22.64         3.68
# 1       PC     17.97      0.00      7.23         1.85
# 2      PS3     25.54     11.22     22.05         9.37
# 3      PS4    130.04     15.02     98.61        44.48
# 4      PSP      0.00      0.36      0.00         0.00
# 5      PSV      3.53     14.54      2.52         1.81
# 6      Wii      2.59      0.00      2.08         0.40
# 7     WiiU     13.15      7.31     19.36         3.16
# 8     X360     15.49      0.08     28.30         4.35
# 9     XOne     46.25      0.32     81.27        12.52
# Text(0.5, 1.0, 'Популярные платформы в остальном мире')

# %%
reg_gen = data_11.pivot_table(index = 'genre', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc = sum).reset_index()
display(reg_gen) # Смотрим в общем как дела, самые продаваемые жанры на разных рынках)

reg_gen.sort_values('eu_sales', ascending=False).head(5).plot(x='eu_sales', y='genre', kind='scatter',  grid=True)
plt.title('Популярные жанры в Европе')
reg_gen.sort_values('na_sales', ascending=False).head(5).plot(x='na_sales', y='genre', kind='scatter',  grid=True)
plt.title('Популярные жанры в Северной Америке')
reg_gen.sort_values('jp_sales', ascending=False).head(5).plot(x='jp_sales', y='genre', kind='scatter',  grid=True)
plt.title('Популярные жанры в Японии')
reg_gen.sort_values('other_sales', ascending=False).head(5).plot(x='other_sales', y='genre', kind='scatter',  grid=True)
plt.title('Популярные жанры в остальном мире')
# Out:
#            genre  eu_sales  jp_sales  na_sales  other_sales
# 0         Action     74.68     29.58     72.53        22.57
# 1      Adventure      6.49      3.60      5.64         1.82
# 2       Fighting      6.69      6.37     12.43         2.73
# 3           Misc     12.86      5.61     15.05         4.03
# 4       Platform      6.80      2.69      6.79         1.81
# 5         Puzzle      0.52      0.93      0.65         0.11
# 6         Racing     14.13      1.76      8.74         2.89
# 7   Role-Playing     28.17     31.16     33.47         8.64
# 8        Shooter     65.52      4.87     79.02        21.53
# 9     Simulation      7.30      2.31      2.63         0.89
# 10        Sports     45.73      3.26     46.13        14.36
# 11      Strategy      1.79      0.95      0.98         0.24
# Text(0.5, 1.0, 'Популярные жанры в остальном мире')

# %%
rating_top = data_11.pivot_table(index = 'rating', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc = sum).reset_index()
display(rating_top) # Смотрим в общем как дела)

rating_top.sort_values('eu_sales', ascending=False).head(5).plot(x='eu_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Европе')
rating_top.sort_values('na_sales', ascending=False).head(5).plot(x='na_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Северной Америке')
rating_top.sort_values('jp_sales', ascending=False).head(5).plot(x='jp_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Японии')
rating_top.sort_values('other_sales', ascending=False).head(5).plot(x='other_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в остальном мире')
# Out:
#   rating  eu_sales  jp_sales  na_sales  other_sales
# 0      E     58.06      8.94     50.74        15.39
# 1   E10+     26.16      4.46     33.23         7.83
# 2      M     93.44      8.01     96.42        28.67
# 3      T     34.07     14.78     38.95        11.33
# Text(0.5, 1.0, 'Популярный рейтинг в остальном мире')

# %%
data_11['rating'] = data_11['rating'].fillna('unknown')
rating_top = data_11.pivot_table(index = 'rating', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc = sum).reset_index()
display(rating_top) # Смотрим в общем как дела)

rating_top.sort_values('eu_sales', ascending=False).head(5).plot(x='eu_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Европе')
rating_top.sort_values('na_sales', ascending=False).head(5).plot(x='na_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Северной Америке')
rating_top.sort_values('jp_sales', ascending=False).head(5).plot(x='jp_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в Японии')
rating_top.sort_values('other_sales', ascending=False).head(5).plot(x='other_sales', y='rating', kind='scatter',  grid=True)
plt.title('Популярный рейтинг в остальном мире')
# Out:
# /tmp/ipykernel_63/898264613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_11['rating'] = data_11['rating'].fillna('unknown')
#     rating  eu_sales  jp_sales  na_sales  other_sales
# 0        E     58.06      8.94     50.74        15.39
# 1     E10+     26.16      4.46     33.23         7.83
# 2        M     93.44      8.01     96.42        28.67
# 3        T     34.07     14.78     38.95        11.33
# 4  unknown     58.95     56.90     64.72        18.40
# Text(0.5, 1.0, 'Популярный рейтинг в остальном мире')

# %% [markdown]
# <div style="border:solid Orange 2px; padding: 40px">
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='Orange'><b>Некоторые рекомендации 💡:</b> </font>
#
# Столбчатый график подойдет для этой визуализации лучше, чем точечный.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# subplots может помочь построить 3 графика рядом, так их проще будет сравнивать.
#
# </div>

# %% [markdown]
# <br/>
# <div style="border:solid Red 2px; padding: 40px">
#     <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах. Может быть стоило пропуски в рейтингах заменить на значение-заглушку? Исправь этот момент и прокомментируй разницу, если она будет. Напиши свои размышления в выводе к этому пункту, где и почему чаще всего покупают игры без рейтинга.
#
#
# </div>

# %% [markdown]
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#
# Европа - PS3, PS4, X360 (Тут весьма все ровно есть три лидера разрыв между ними не очень большой)
# Северная Америка - X360, PS3, PS4 (Тут 2 основных лидера это PS3, X360)
# Япония - 3DS, PS3, PSP (Где wii?) - но при этом 3DS на голову опережает конкурентов.
# Остольной МИР - PS3, PS4, X360 - Самые популярные это PS3 b PS4.
#
# Самые популярные жанры (топ-5). Поясните разницу.
#
# Европа - Action  и Shooter, далее идет Sport что конечно радует Fifa наше всё)
# Северная Америка - Action  и Shooter наголову опережают остальные жанры
# Япония - Role-Playing и Action Рынок в японии особенный это надо учитывать!
# Остольной МИР - (тут идентично с Европой) Action  и Shooter, далее идет Sport что конечно радует Fifa наше всё)
#
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
# Тут в целом во всем мире одинаковые результаты, но сильно отличается Япония пологаю что игры жанра Role-Playing не такие жестокие и имеют в основном рейтинги E и T.
#
# ***Игры без рейтинга ESRB по продажам занимают 2-ю позицию (мне кажется что рейтинг мало на что влияет)
# В Японии игры без рейтинга в продажах занимают подавляющее количество! Либо рейтинговая система там совсем не работает, либо у них есть какаято своя система данных о которой у нас нет.
#
#
# ***Европа - PS4 на голову лидирует, Хопе и PS4 замыкают тройку лидеров
# (Если считать по данным с 2014 года результат обсолютно другой)
# Северная Америка - PS4, Хопе, X360 (Тут 2 основных лидера это PS4, Хопе)
# Япония - 3DS, PS4, PSV - но при этом 3DS на голову опережает конкурентов.
# Остольной МИР - PS4, Хопе, PS4 - Самые популярные это PS4 и Хопе.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Верно, в Японии действует рейтинговая система CERO.

# %% [markdown]
# <div style="border:solid Red 2px; padding: 40px">
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Добавь, пожалуйста, формулировку нулевой и альтернативной гипотез для обеих проверок.
#
# </div>

# %% [markdown]
# ***Часть 5. Проверки гипотез
#
# 1) Нулевая гипотиза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#    Альтернативная гипотиза: Средние пользовательские рейтинги платформ Xbox One и PC разные.
#
# 2) Нулевая гипотиза: Средние пользовательские рейтинги жанров Action и Sports одинаковые.
#    Альтернативная гипотиза: Средние пользовательские рейтинги жанров Action и Sports разные.
#
#
#    ***Добавил альтернативные гипотизы

# %%
from scipy import stats as st
#print(data_11)
#print(data_11['platform'].unique())

#print(data_11['user_score'].unique())

xone = data_11[(data_11['platform'] == 'XOne')]['user_score']
pc = data_11[(data_11['platform'] == 'PC')]['user_score']
#print(pc)


results = st.ttest_ind(xone.dropna(), pc.dropna(), equal_var=False) #вызов метода для проверки гипотезы
#print(results)
alpha = .05 #задаем значение уровня значимости

print(results.pvalue) # вывод значения p-value на экран 
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
    
    
print()
print()

action = data_11[(data_11['genre'] == 'Action')]['user_score']
sports = data_11[(data_11['genre'] == 'Sports')]['user_score']
#print(pc)


results = st.ttest_ind(action.dropna(), sports.dropna(), equal_var=False) #вызов метода для проверки гипотезы
#print(results)
alpha = .05 #задаем значение уровня значимости

print(results.pvalue) # вывод значения p-value на экран 
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 0.11601398086668832
# Не получилось отвергнуть нулевую гипотезу
#
#
# 1.1825550382644557e-14
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div style="border:solid Red 2px; padding: 40px">
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера_V2 <a class="tocSkip"></h2>
#
#
#
#
# <b>На доработку ❌:</b>
#
# Стоит сформулировать нулевую и альтернативную гипотезу для каждой прверки. Обрати внимание, что нулевая гипотеза должна говорить, что отличий между выборками совокупностей, которые мы сравниваем по одному из признаков нет, а альтернативная - отличия есть.
#
# Исходя из формулировок нулевых и альтернативных гипотез и результата проверок стат.теста (отвергаем или не отвергаем нулевую гипотезу), скорректируй вывод.

# %% [markdown]
# <div style="border:solid Red 2px; padding: 40px">
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку ❌:</b>
#
# Зачем ты фильтруешь в оенках значения минус 1? Ты не ставил таких заглушек.
#
# Обрати внимание, что нулевая гипотеза должна отвергаться, гогда results.pvalue < alpha.
#
# Поправь и скорректируй вывод для каждой гипотезы.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Верно выбран двусторонний тест. Молодец, что не забываешь удалять пропуски перед проверкой гипотез. Отлично, что выводишь значение `results.pvalue`, в случае, если оно расчиталось не верно (например, равно NaN) - это можно сразу увидеть.
#
#
# </div>

# %% [markdown]
# ***Проверка нулевых и альтернативных гипотез
#
# 1) Нулевая гипотиза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Альтернативная гипотиза: Средние пользовательские рейтинги платформ Xbox One и PC разные.
#
# 2) Нулевая гипотиза: Средние пользовательские рейтинги жанров Action и Sports одинаковые. Альтернативная гипотиза: Средние пользовательские рейтинги жанров Action и Sports разные.
#
# 1 - Не получилось отвергнуть нулевую гипотезу, средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
#
# 2 - Отвергаем нулевую гипотезу, средние пользовательские рейтинги жанров Action  и Sports разные.

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера_V3 <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
# Вывод верный

# %% [markdown]
# ***Общий вывод
#
# На что стоит обратить в нимание при планировани рекламных кампаний в 2017 году.
# В общем рынок идёт на спад и в 2017 году это продолжится, мы это понимаем из первой гистограммы видя цикличные (5 лет) пики!
# А определив средний срок нахождения на рынке платформ (7 лет) мы понимаем что те платформы ('PS4', '3DS', 'XOne', 'WiiU', 'PC') которые уже выпущенны прошли свой пик и начали снижения.
#
# В 2017 году в рекламных компаниях будем оператся на данные консоли PS4, 3DS, XBOX, Wii, PC у них максимальные продажи.
# Теперь перейдем к рынкам сбыта исходя из полученных данных мы очень четко видим что рынок Японии очень сильно отличается от Европейского и Северо Американского. Для  Японии нужно делать акценты в рекламных кампаниях на данные 3DS, PS3, PSP платформы и жанры Role-Playing и Action! А в Европе и Америке на жанры Action и Shooter (Для европы также актуален Спорт) и платформы PS3, PS4, X360
#
# Обращая внимание на рейтинг есть интересное замечание что в целом рейтинги игр выходящих в этой стране меньше поэтому и реламу нужно адаптировать на более широкий круг аудитории.
#
#
# ***В 2017 году в рекламных компаниях будем оператся на данные консоли PS4, 3DS, XBOX, Wii, PC у них максимальные продажи.
# Теперь перейдем к рынкам сбыта исходя из полученных данных мы очень четко видим что рынок Японии очень сильно отличается от Европейского и Северо Американского. Для  Японии нужно делать акценты в рекламных кампаниях на данные 3DS, PS4, PSV платформы и жанры Role-Playing и Action! А в Европе и Америке на жанры Action и Shooter (Для европы также актуален Спорт) и платформы PS4, Хопе и PS4

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <font color='green'><b>Все отлично! 👍:</b>  </font>
#
#
# Пожалуйста, исправь те ячейки, где я оставила комментарии красным и обязательно посмотри, относятся ли твои будущие изменения к полному выводу.
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <h2> Общий вывод по проекту <a class="tocSkip"> </h2>
#
# Спасибо за твой проект! Проделана большая работа, и видно твое внимательное отношение к содержанию анализа и к оформлению. Ты молодец! Практически все ключевые этапы работы над проектом выполнены, код логичен и понятен, комментарии и выводы написаны, так что в целом справиться с задачей тебе удалось. Возле моментов, на которые стоит обратить внимание, я оставила комментарии.
#
# **Отдельно хочу отметить положительные моменты в твоей работе:**
#
# * На всех этапах тобой предложены интересные решения и методы для их реализации.
# * Ты грамотно используешь визуализацию. Это здорово, т.к. помогает быстро считать информацию получателю отчета.
# * Ты грамотно делаешь выводы, на основе полученной информации.
#
# **Моменты, требующие внимания:**
#
#
# * Стоит добавить заголовок и введение в проект.
# * Структурируй свой проект, пиши промежуточные выводы, обозначай переход к подразделам, пиши свои размышления и действия, которые выполняешь.
# * Не все пропуски обработаны и прокомментированы. Опиши причины, которые могли привести к пропускам.
# * Сделай проверку на дубликаты.
# * Скорректируй анализ динамики выпуска игр по годам. Дополни вывод, какой период совсем не значим для анализа, когда было критически мало игр?
# * Поправь актуальный период.
# * Нужно доработать анализ корреляции.
# * Стоит оценить прибыльность жанров на основе средних или медианных продаж.
# * Нужно добавить в оценку влияния вида возрастного рейтинга ESRB на продажи игры, в которых рейтинг не указан, внеси полученные результаты в вывод.
# * Скорректируй проверку гипотез.
# * И обязательно соотнести итоговый вывод, после учета всех комментариев.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
# **Желаю удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <h3> Комментарий ревьюера_V2 <a class="tocSkip"> </h3>
#
# Илья, спасибо за твои корректировки. Осталось немного поправить в проверке гипотез. Жду твой проект снова.
#
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; padding: 40px">
# <h2> Комментарий ревьюера_V3 <a class="tocSkip"> </h2>
#
# Спасибо за доработку. Надеюсь мои комментарии были полезны. Проект принят. Желаю удачи в дальнейшем обучении.
#
# </div>
